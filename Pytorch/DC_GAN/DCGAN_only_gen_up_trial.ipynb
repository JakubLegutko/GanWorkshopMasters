# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import datasets, transforms
from torchvision.utils import save_image
import time
import matplotlib.pyplot as plt
import numpy as np
from torchviz import make_dot
from torchinfo import summary
# Define constants
IMG_SIZE = 512  # Updated to 512x512 for the new output size
LATENT_DIM = 200  # Latent dimension remains the same
BATCH_SIZE = 7  # Adjust based on your GPU memory; decrease if you encounter memory errors
EPOCHS = 100
epoch_times = []  # List to store time taken for each epoch
d_loss_values = []
g_loss_values = []
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.init_size = IMG_SIZE // 32  # Adjusted for 512x512 images
        self.l1 = nn.Sequential(nn.Linear(LATENT_DIM, 256 * self.init_size ** 2))
        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(256),
            nn.Upsample(scale_factor=2),  # Upsample to (16,16)
            nn.Conv2d(256, 256, 3, stride=1, padding=1),
            nn.BatchNorm2d(256, 0.8),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2),  # Upsample to (32,32)
            nn.Conv2d(256, 256, 3, stride=1, padding=1),
            nn.BatchNorm2d(256, 0.8),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2),  # Upsample to (64,64)
            nn.Conv2d(256, 128, 3, stride=1, padding=1),
            nn.BatchNorm2d(128, 0.8),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2),  # Upsample to (128,128)
            nn.Conv2d(128, 64, 3, stride=1, padding=1),
            nn.BatchNorm2d(64, 0.8),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2),  # Upsample to (256,256)
            nn.Conv2d(64, 32, 3, stride=1, padding=1),
            nn.BatchNorm2d(32, 0.8),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2),  # Upsample to (512,512)
            nn.Conv2d(32, 16, 3, stride=1, padding=1),
            nn.BatchNorm2d(16, 0.8),
            nn.ReLU(inplace=True),
            nn.Conv2d(16, 3, 3, stride=1, padding=1),
            nn.Tanh()
        )
    def forward(self, z):
        out = self.l1(z)
        out = out.view(out.shape[0], 256, self.init_size, self.init_size)
        img = self.conv_blocks(out)
        return img
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, 4, stride=2, padding=1),  # Output: (batch_size, 64, 128, 128)
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  # Output: (batch_size, 128, 64, 64)
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, stride=2, padding=1),  # Output: (batch_size, 256, 32, 32)
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, 4, stride=2, padding=1),  # Output: (batch_size, 512, 16, 16)
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1024, 4, stride=2, padding=1),  # Output: (batch_size, 1024, 8, 8)
            nn.BatchNorm2d(1024),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Flatten(),
            nn.Linear(1024 * 8 * 8, 1),
            nn.Sigmoid()
        )
    def forward(self, img):
        validity = self.model(img)
        return validity
transform = transforms.Compose([
    transforms.Resize(256),  # Keep dataset images at 256x256
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])
dataloader = DataLoader(
    ConcatDataset([
        datasets.Flowers102(root='../../data/flowers', split='train', download=True, transform=transform),
        datasets.Flowers102(root='../../data/flowers', split='val', download=True, transform=transform),
        datasets.Flowers102(root='../../data/flowers', split='test', download=True, transform=transform)
    ]),
    batch_size=BATCH_SIZE, shuffle=True
)
# Initialize models
generator = Generator().to(device)
discriminator = Discriminator().to(device)
# Generate and save summary for Generator model
generator_summary = summary(generator, input_size=(1, LATENT_DIM), verbose=2, col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"])
with open("generator_summary_512_upsample.txt", "w", encoding="utf-8") as f:
    f.write(str(generator_summary))
# Generate and save summary for Discriminator model
discriminator_summary = summary(discriminator, input_size=(1, 3, 256, 256), verbose=2, col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"])
with open("discriminator_summary_512_upsample.txt", "w", encoding="utf-8") as f:
    f.write(str(discriminator_summary))
# Visualize the Generator Model
z_sample = torch.randn(1, LATENT_DIM).to(device)  # A single sample input for the generator
gen_sample_output = generator(z_sample)
gen_dot = make_dot(gen_sample_output, params=dict(generator.named_parameters()))
gen_dot.render("generator_architecture_512_upsample", format="png")  # Save the visualization as a PNG file
# Visualize the Discriminator Model
real_img_sample = torch.randn(1, 3, 256, 256).to(device)  # A single sample input for the discriminator
disc_sample_output = discriminator(real_img_sample)
disc_dot = make_dot(disc_sample_output, params=dict(discriminator.named_parameters()))
disc_dot.render("discriminator_architecture_512_upsample", format="png")  # Save the visualization as a PNG file
# Loss function
adversarial_loss = nn.BCELoss()
# Optimizers
optimizer_G = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=0.0005, betas=(0.5, 0.999))
# Training
for epoch in range(EPOCHS):
    epoch_start_time = time.time()  # Start time for the epoch
    for i, (imgs, _) in enumerate(dataloader):
        # Calculate and print GPU memory usage
        if torch.cuda.is_available():
            allocated_memory = torch.cuda.memory_allocated() / (1024 ** 3)  # Convert to GB
            reserved_memory = torch.cuda.memory_reserved() / (1024 ** 3)    # Convert to GB
            print(f"[GPU Memory Allocated: {allocated_memory:.2f} GB] [GPU Memory Reserved: {reserved_memory:.2f} GB]")
        # Configure input
        real_imgs = imgs.to(device)
        batch_size = real_imgs.size(0)
        # Adversarial ground truths
        valid = torch.ones(batch_size, 1, requires_grad=False).to(device)
        fake = torch.zeros(batch_size, 1, requires_grad=False).to(device)
        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        # Sample noise as generator input
        z = torch.randn(batch_size, LATENT_DIM).to(device)
        # Generate a batch of 512x512 images
        gen_imgs_512 = generator(z)
        # Resize generated images to 256x256 for the discriminator
        gen_imgs_256 = nn.functional.interpolate(gen_imgs_512, size=(256, 256), mode='bilinear', align_corners=False)
        # Loss for real images
        real_loss = adversarial_loss(discriminator(real_imgs), valid)
        # Loss for fake images
        fake_loss = adversarial_loss(discriminator(gen_imgs_256.detach()), fake)
        # Total discriminator loss
        d_loss = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_D.step()
        # -----------------
        #  Train Generator
        # -----------------
        optimizer_G.zero_grad()
        # Loss for fake images with flipped labels
        g_loss = adversarial_loss(discriminator(gen_imgs_256), valid)
        g_loss.backward()
        optimizer_G.step()
        print(f"[Epoch {epoch}/{EPOCHS}] [Batch {i}/{len(dataloader)}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}]")
    # Save sample 512x512 images
    if epoch % 2 == 0:
        save_image(gen_imgs_512.data[:25], f"images/{epoch}_DCGAN_flowers2_512_upsample.png", nrow=5, normalize=True)
        # Save the model
        torch.save(generator.state_dict(), f"saved_model_dcgan_flower2_512_upsample_{epoch}.pth")
        d_loss_values.append(d_loss.item())
        g_loss_values.append(g_loss.item())
    epoch_end_time = time.time()  # End time for the epoch
    epoch_duration = epoch_end_time - epoch_start_time  # Duration of the epoch
    epoch_times.append(epoch_duration)  # Append the duration to the list
# Save model after last epoch
save_image(gen_imgs_512.data[:25], f"images/{EPOCHS}_DCGAN_flowers2_512_upsample.png", nrow=5, normalize=True)
# Save the model
torch.save(generator.state_dict(), f"saved_model_dcgan_flower2_512_upsample_{EPOCHS}.pth")
# Calculate average time per epoch
average_time_per_epoch = sum(epoch_times) / len(epoch_times)
print(f"Average time per epoch: {average_time_per_epoch:.2f} seconds")
# Plot and save loss curves
plt.plot(np.arange(0, EPOCHS, 2), d_loss_values, label='Discriminator loss')
plt.plot(np.arange(0, EPOCHS, 2), g_loss_values, label='Generator loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss values')
plt.savefig('loss_values_flowers_512_upsample.png')
plt.show()
# Plot and save time per epoch
plt.plot(np.arange(0, EPOCHS), epoch_times)
plt.title("Time taken per epoch")
plt.xlabel("Epoch")
plt.ylabel("Time (s)")
plt.savefig("time_per_epoch_flowers_512_upsample.png")
plt.show()
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# =====================================================================================================================================================================
# Generator                                [1, 200]                  [1, 3, 1024, 1024]        --                        --                        --
# ├─Sequential: 1-1                        [1, 200]                  [1, 65536]                --                        --                        --
# │    └─0.weight                                                                              ├─13,107,200              [65536, 200]
# │    └─0.bias                                                                                └─65,536                  [65536]
# │    └─Linear: 2-1                       [1, 200]                  [1, 65536]                13,172,736                --                        13,172,736
# │    │    └─weight                                                                           ├─13,107,200              [200, 65536]
# │    │    └─bias                                                                             └─65,536                  [65536]
# ├─Sequential: 1-2                        [1, 256, 16, 16]          [1, 3, 1024, 1024]        --                        --                        --
# │    └─0.weight                                                                              ├─256                     [256]
# │    └─0.bias                                                                                ├─256                     [256]
# │    └─2.weight                                                                              ├─589,824                 [256, 256, 3, 3]
# │    └─2.bias                                                                                ├─256                     [256]
# │    └─3.weight                                                                              ├─256                     [256]
# │    └─3.bias                                                                                ├─256                     [256]
# │    └─6.weight                                                                              ├─589,824                 [256, 256, 3, 3]
# │    └─6.bias                                                                                ├─256                     [256]
# │    └─7.weight                                                                              ├─256                     [256]
# │    └─7.bias                                                                                ├─256                     [256]
# │    └─10.weight                                                                             ├─294,912                 [128, 256, 3, 3]
# │    └─10.bias                                                                               ├─128                     [128]
# │    └─11.weight                                                                             ├─128                     [128]
# │    └─11.bias                                                                               ├─128                     [128]
# │    └─14.weight                                                                             ├─73,728                  [64, 128, 3, 3]
# │    └─14.bias                                                                               ├─64                      [64]
# │    └─15.weight                                                                             ├─64                      [64]
# │    └─15.bias                                                                               ├─64                      [64]
# │    └─18.weight                                                                             ├─18,432                  [32, 64, 3, 3]
# │    └─18.bias                                                                               ├─32                      [32]
# │    └─19.weight                                                                             ├─32                      [32]
# │    └─19.bias                                                                               ├─32                      [32]
# │    └─22.weight                                                                             ├─4,608                   [16, 32, 3, 3]
# │    └─22.bias                                                                               ├─16                      [16]
# │    └─23.weight                                                                             ├─16                      [16]
# │    └─23.bias                                                                               ├─16                      [16]
# │    └─25.weight                                                                             ├─432                     [3, 16, 3, 3]
# │    └─25.bias                                                                               └─3                       [3]
# │    └─BatchNorm2d: 2-2                  [1, 256, 16, 16]          [1, 256, 16, 16]          512                       --                        512
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─Upsample: 2-3                     [1, 256, 16, 16]          [1, 256, 32, 32]          --                        --                        --
# │    └─Conv2d: 2-4                       [1, 256, 32, 32]          [1, 256, 32, 32]          590,080                   [3, 3]                    604,241,920
# │    │    └─weight                                                                           ├─589,824                 [256, 256, 3, 3]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─BatchNorm2d: 2-5                  [1, 256, 32, 32]          [1, 256, 32, 32]          512                       --                        512
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─ReLU: 2-6                         [1, 256, 32, 32]          [1, 256, 32, 32]          --                        --                        --
# │    └─Upsample: 2-7                     [1, 256, 32, 32]          [1, 256, 64, 64]          --                        --                        --
# │    └─Conv2d: 2-8                       [1, 256, 64, 64]          [1, 256, 64, 64]          590,080                   [3, 3]                    2,416,967,680
# │    │    └─weight                                                                           ├─589,824                 [256, 256, 3, 3]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─BatchNorm2d: 2-9                  [1, 256, 64, 64]          [1, 256, 64, 64]          512                       --                        512
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─ReLU: 2-10                        [1, 256, 64, 64]          [1, 256, 64, 64]          --                        --                        --
# │    └─Upsample: 2-11                    [1, 256, 64, 64]          [1, 256, 128, 128]        --                        --                        --
# │    └─Conv2d: 2-12                      [1, 256, 128, 128]        [1, 128, 128, 128]        295,040                   [3, 3]                    4,833,935,360
# │    │    └─weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    │    └─bias                                                                             └─128                     [128]
# │    └─BatchNorm2d: 2-13                 [1, 128, 128, 128]        [1, 128, 128, 128]        256                       --                        256
# │    │    └─weight                                                                           ├─128                     [128]
# │    │    └─bias                                                                             └─128                     [128]
# │    └─ReLU: 2-14                        [1, 128, 128, 128]        [1, 128, 128, 128]        --                        --                        --
# │    └─Upsample: 2-15                    [1, 128, 128, 128]        [1, 128, 256, 256]        --                        --                        --
# │    └─Conv2d: 2-16                      [1, 128, 256, 256]        [1, 64, 256, 256]         73,792                    [3, 3]                    4,836,032,512
# │    │    └─weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    │    └─bias                                                                             └─64                      [64]
# │    └─BatchNorm2d: 2-17                 [1, 64, 256, 256]         [1, 64, 256, 256]         128                       --                        128
# │    │    └─weight                                                                           ├─64                      [64]
# │    │    └─bias                                                                             └─64                      [64]
# │    └─ReLU: 2-18                        [1, 64, 256, 256]         [1, 64, 256, 256]         --                        --                        --
# │    └─Upsample: 2-19                    [1, 64, 256, 256]         [1, 64, 512, 512]         --                        --                        --
# │    └─Conv2d: 2-20                      [1, 64, 512, 512]         [1, 32, 512, 512]         18,464                    [3, 3]                    4,840,226,816
# │    │    └─weight                                                                           ├─18,432                  [64, 32, 3, 3]
# │    │    └─bias                                                                             └─32                      [32]
# │    └─BatchNorm2d: 2-21                 [1, 32, 512, 512]         [1, 32, 512, 512]         64                        --                        64
# │    │    └─weight                                                                           ├─32                      [32]
# │    │    └─bias                                                                             └─32                      [32]
# │    └─ReLU: 2-22                        [1, 32, 512, 512]         [1, 32, 512, 512]         --                        --                        --
# │    └─Upsample: 2-23                    [1, 32, 512, 512]         [1, 32, 1024, 1024]       --                        --                        --
# │    └─Conv2d: 2-24                      [1, 32, 1024, 1024]       [1, 16, 1024, 1024]       4,624                     [3, 3]                    4,848,615,424
# │    │    └─weight                                                                           ├─4,608                   [32, 16, 3, 3]
# │    │    └─bias                                                                             └─16                      [16]
# │    └─BatchNorm2d: 2-25                 [1, 16, 1024, 1024]       [1, 16, 1024, 1024]       32                        --                        32
# │    │    └─weight                                                                           ├─16                      [16]
# │    │    └─bias                                                                             └─16                      [16]
# │    └─ReLU: 2-26                        [1, 16, 1024, 1024]       [1, 16, 1024, 1024]       --                        --                        --
# │    └─Conv2d: 2-27                      [1, 16, 1024, 1024]       [1, 3, 1024, 1024]        435                       [3, 3]                    456,130,560
# │    │    └─weight                                                                           ├─432                     [16, 3, 3, 3]
# │    │    └─bias                                                                             └─3                       [3]
# │    └─Tanh: 2-28                        [1, 3, 1024, 1024]        [1, 3, 1024, 1024]        --                        --                        --
# =====================================================================================================================================================================
# Total params: 14,747,267
# Trainable params: 14,747,267
# Non-trainable params: 0
# Total mult-adds (G): 22.85
# =====================================================================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 550.50
# Params size (MB): 58.99
# Estimated Total Size (MB): 609.49
# =====================================================================================================================================================================
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# =====================================================================================================================================================================
# Discriminator                            [1, 3, 256, 256]          [1, 1]                    --                        --                        --
# ├─Sequential: 1-1                        [1, 3, 256, 256]          [1, 1]                    --                        --                        --
# │    └─0.weight                                                                              ├─3,072                   [64, 3, 4, 4]
# │    └─0.bias                                                                                ├─64                      [64]
# │    └─2.weight                                                                              ├─131,072                 [128, 64, 4, 4]
# │    └─2.bias                                                                                ├─128                     [128]
# │    └─3.weight                                                                              ├─128                     [128]
# │    └─3.bias                                                                                ├─128                     [128]
# │    └─5.weight                                                                              ├─524,288                 [256, 128, 4, 4]
# │    └─5.bias                                                                                ├─256                     [256]
# │    └─6.weight                                                                              ├─256                     [256]
# │    └─6.bias                                                                                ├─256                     [256]
# │    └─8.weight                                                                              ├─2,097,152               [512, 256, 4, 4]
# │    └─8.bias                                                                                ├─512                     [512]
# │    └─9.weight                                                                              ├─512                     [512]
# │    └─9.bias                                                                                ├─512                     [512]
# │    └─11.weight                                                                             ├─8,388,608               [1024, 512, 4, 4]
# │    └─11.bias                                                                               ├─1,024                   [1024]
# │    └─12.weight                                                                             ├─1,024                   [1024]
# │    └─12.bias                                                                               ├─1,024                   [1024]
# │    └─15.weight                                                                             ├─65,536                  [1, 65536]
# │    └─15.bias                                                                               └─1                       [1]
# │    └─Conv2d: 2-1                       [1, 3, 256, 256]          [1, 64, 128, 128]         3,136                     [4, 4]                    51,380,224
# │    │    └─weight                                                                           ├─3,072                   [3, 64, 4, 4]
# │    │    └─bias                                                                             └─64                      [64]
# │    └─LeakyReLU: 2-2                    [1, 64, 128, 128]         [1, 64, 128, 128]         --                        --                        --
# │    └─Conv2d: 2-3                       [1, 64, 128, 128]         [1, 128, 64, 64]          131,200                   [4, 4]                    537,395,200
# │    │    └─weight                                                                           ├─131,072                 [64, 128, 4, 4]
# │    │    └─bias                                                                             └─128                     [128]
# │    └─BatchNorm2d: 2-4                  [1, 128, 64, 64]          [1, 128, 64, 64]          256                       --                        256
# │    │    └─weight                                                                           ├─128                     [128]
# │    │    └─bias                                                                             └─128                     [128]
# │    └─LeakyReLU: 2-5                    [1, 128, 64, 64]          [1, 128, 64, 64]          --                        --                        --
# │    └─Conv2d: 2-6                       [1, 128, 64, 64]          [1, 256, 32, 32]          524,544                   [4, 4]                    537,133,056
# │    │    └─weight                                                                           ├─524,288                 [128, 256, 4, 4]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─BatchNorm2d: 2-7                  [1, 256, 32, 32]          [1, 256, 32, 32]          512                       --                        512
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# │    └─LeakyReLU: 2-8                    [1, 256, 32, 32]          [1, 256, 32, 32]          --                        --                        --
# │    └─Conv2d: 2-9                       [1, 256, 32, 32]          [1, 512, 16, 16]          2,097,664                 [4, 4]                    537,001,984
# │    │    └─weight                                                                           ├─2,097,152               [256, 512, 4, 4]
# │    │    └─bias                                                                             └─512                     [512]
# │    └─BatchNorm2d: 2-10                 [1, 512, 16, 16]          [1, 512, 16, 16]          1,024                     --                        1,024
# │    │    └─weight                                                                           ├─512                     [512]
# │    │    └─bias                                                                             └─512                     [512]
# │    └─LeakyReLU: 2-11                   [1, 512, 16, 16]          [1, 512, 16, 16]          --                        --                        --
# │    └─Conv2d: 2-12                      [1, 512, 16, 16]          [1, 1024, 8, 8]           8,389,632                 [4, 4]                    536,936,448
# │    │    └─weight                                                                           ├─8,388,608               [512, 1024, 4, 4]
# │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─BatchNorm2d: 2-13                 [1, 1024, 8, 8]           [1, 1024, 8, 8]           2,048                     --                        2,048
# │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─LeakyReLU: 2-14                   [1, 1024, 8, 8]           [1, 1024, 8, 8]           --                        --                        --
# │    └─Flatten: 2-15                     [1, 1024, 8, 8]           [1, 65536]                --                        --                        --
# │    └─Linear: 2-16                      [1, 65536]                [1, 1]                    65,537                    --                        65,537
# │    │    └─weight                                                                           ├─65,536                  [65536, 1]
# │    │    └─bias                                                                             └─1                       [1]
# │    └─Sigmoid: 2-17                     [1, 1]                    [1, 1]                    --                        --                        --
# =====================================================================================================================================================================
# Total params: 11,215,553
# Trainable params: 11,215,553
# Non-trainable params: 0
# Total mult-adds (G): 2.20
# =====================================================================================================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 24.12
# Params size (MB): 44.86
# Estimated Total Size (MB): 69.77
# =====================================================================================================================================================================
# [GPU Memory Allocated: 0.61 GB] [GPU Memory Reserved: 0.63 GB]
# [Epoch 0/100] [Batch 0/1170] [D loss: 0.745958] [G loss: 18.132641]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1/1170] [D loss: 0.000163] [G loss: 18.120533]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 2/1170] [D loss: 0.000274] [G loss: 18.063433]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 3/1170] [D loss: 0.000176] [G loss: 17.980972]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 4/1170] [D loss: 0.000012] [G loss: 17.883064]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 5/1170] [D loss: 0.000007] [G loss: 17.820555]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 6/1170] [D loss: 0.000018] [G loss: 17.711401]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 7/1170] [D loss: 0.000003] [G loss: 17.171906]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 8/1170] [D loss: 0.000057] [G loss: 15.016275]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 9/1170] [D loss: 0.001288] [G loss: 14.689359]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 10/1170] [D loss: 0.006842] [G loss: 22.465986]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 11/1170] [D loss: 0.088037] [G loss: 0.000038]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 12/1170] [D loss: 12.574757] [G loss: 25.519716]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 13/1170] [D loss: 0.179959] [G loss: 8.553749]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 14/1170] [D loss: 0.923260] [G loss: 20.421509]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 15/1170] [D loss: 1.679156] [G loss: 5.986014]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 16/1170] [D loss: 1.136301] [G loss: 24.271114]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 17/1170] [D loss: 0.735364] [G loss: 16.250008]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 18/1170] [D loss: 0.014854] [G loss: 7.030237]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 19/1170] [D loss: 0.446048] [G loss: 18.525013]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 20/1170] [D loss: 0.019874] [G loss: 17.880482]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 21/1170] [D loss: 0.000606] [G loss: 17.018820]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 22/1170] [D loss: 0.269940] [G loss: 1.187982]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 23/1170] [D loss: 3.825259] [G loss: 34.441223]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 24/1170] [D loss: 1.384305] [G loss: 8.013647]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 25/1170] [D loss: 0.039253] [G loss: 1.860552]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 26/1170] [D loss: 0.934666] [G loss: 16.031162]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 27/1170] [D loss: 0.106513] [G loss: 10.745710]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 28/1170] [D loss: 0.011351] [G loss: 9.681591]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 29/1170] [D loss: 0.082902] [G loss: 19.263344]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 30/1170] [D loss: 0.122192] [G loss: 14.049668]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 31/1170] [D loss: 0.012842] [G loss: 9.409037]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 32/1170] [D loss: 0.246916] [G loss: 28.967880]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 33/1170] [D loss: 0.891083] [G loss: 6.919511]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 34/1170] [D loss: 0.655914] [G loss: 25.859556]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 35/1170] [D loss: 0.095761] [G loss: 20.575935]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 36/1170] [D loss: 2.774500] [G loss: 0.839008]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 37/1170] [D loss: 1.939306] [G loss: 29.351231]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 38/1170] [D loss: 0.044593] [G loss: 28.492088]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 39/1170] [D loss: 0.397172] [G loss: 21.470598]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 40/1170] [D loss: 0.100624] [G loss: 10.470757]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 41/1170] [D loss: 0.853671] [G loss: 40.041145]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 42/1170] [D loss: 2.783377] [G loss: 8.557566]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 43/1170] [D loss: 0.324310] [G loss: 17.405737]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 44/1170] [D loss: 0.001319] [G loss: 13.369146]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 45/1170] [D loss: 0.058261] [G loss: 18.087662]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 46/1170] [D loss: 0.002791] [G loss: 18.760870]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 47/1170] [D loss: 0.241970] [G loss: 7.407729]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 48/1170] [D loss: 0.453586] [G loss: 36.693283]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 49/1170] [D loss: 0.006165] [G loss: 38.180866]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 50/1170] [D loss: 2.077065] [G loss: 0.034097]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 51/1170] [D loss: 18.058846] [G loss: 4.281186]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 52/1170] [D loss: 9.994505] [G loss: 22.860502]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 53/1170] [D loss: 0.755203] [G loss: 21.486628]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 54/1170] [D loss: 0.682407] [G loss: 14.539033]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 55/1170] [D loss: 7.645834] [G loss: 14.487908]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 56/1170] [D loss: 0.946605] [G loss: 26.347494]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 57/1170] [D loss: 0.331397] [G loss: 24.671148]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 58/1170] [D loss: 0.078554] [G loss: 12.092234]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 59/1170] [D loss: 0.000726] [G loss: 10.771762]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 60/1170] [D loss: 2.586846] [G loss: 41.033779]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 61/1170] [D loss: 5.888978] [G loss: 0.203871]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 62/1170] [D loss: 4.500359] [G loss: 5.890084]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 63/1170] [D loss: 0.561008] [G loss: 14.294414]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 64/1170] [D loss: 0.737749] [G loss: 10.276506]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 65/1170] [D loss: 0.677620] [G loss: 1.385100]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 66/1170] [D loss: 1.304034] [G loss: 12.582220]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 67/1170] [D loss: 0.032133] [G loss: 12.642293]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 68/1170] [D loss: 0.405661] [G loss: 6.370777]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 69/1170] [D loss: 1.515504] [G loss: 8.159801]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 70/1170] [D loss: 2.344718] [G loss: 23.278927]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 71/1170] [D loss: 3.086411] [G loss: 3.813291]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 72/1170] [D loss: 0.309727] [G loss: 9.635757]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 73/1170] [D loss: 0.459988] [G loss: 12.155318]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 74/1170] [D loss: 1.414729] [G loss: 3.324226]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 75/1170] [D loss: 1.049070] [G loss: 10.816111]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 76/1170] [D loss: 1.050836] [G loss: 6.677881]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 77/1170] [D loss: 0.921363] [G loss: 13.556363]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 78/1170] [D loss: 0.196958] [G loss: 16.624718]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 79/1170] [D loss: 0.500351] [G loss: 5.477870]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 80/1170] [D loss: 0.659437] [G loss: 12.581254]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 81/1170] [D loss: 1.335077] [G loss: 27.388708]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 82/1170] [D loss: 5.771060] [G loss: 3.773888]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 83/1170] [D loss: 1.228242] [G loss: 8.634296]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 84/1170] [D loss: 0.785214] [G loss: 12.997557]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 85/1170] [D loss: 1.191661] [G loss: 3.029936]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 86/1170] [D loss: 2.488688] [G loss: 9.353751]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 87/1170] [D loss: 0.810145] [G loss: 8.126889]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 88/1170] [D loss: 0.624534] [G loss: 12.352823]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 89/1170] [D loss: 1.119885] [G loss: 14.281949]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 90/1170] [D loss: 0.094647] [G loss: 9.925748]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 91/1170] [D loss: 0.002691] [G loss: 15.046763]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 92/1170] [D loss: 0.375695] [G loss: 15.652870]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 93/1170] [D loss: 0.601818] [G loss: 8.175432]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 94/1170] [D loss: 0.121717] [G loss: 5.647913]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 95/1170] [D loss: 0.302017] [G loss: 3.543911]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 96/1170] [D loss: 7.843777] [G loss: 16.007530]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 97/1170] [D loss: 0.606272] [G loss: 4.899261]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 98/1170] [D loss: 0.176596] [G loss: 11.800954]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 99/1170] [D loss: 0.393107] [G loss: 22.706781]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 100/1170] [D loss: 1.083490] [G loss: 12.263966]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 101/1170] [D loss: 0.058834] [G loss: 5.327904]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 102/1170] [D loss: 1.077813] [G loss: 22.132311]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 103/1170] [D loss: 0.954835] [G loss: 10.925149]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 104/1170] [D loss: 1.087823] [G loss: 2.821613]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 105/1170] [D loss: 9.544706] [G loss: 11.452426]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 106/1170] [D loss: 0.909908] [G loss: 19.584959]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 107/1170] [D loss: 0.792826] [G loss: 4.101197]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 108/1170] [D loss: 0.206206] [G loss: 5.756715]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 109/1170] [D loss: 0.088640] [G loss: 9.288174]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 110/1170] [D loss: 2.182910] [G loss: 11.990605]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 111/1170] [D loss: 0.661276] [G loss: 20.205341]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 112/1170] [D loss: 1.529492] [G loss: 8.388371]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 113/1170] [D loss: 0.033773] [G loss: 5.132700]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 114/1170] [D loss: 0.665620] [G loss: 18.721821]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 115/1170] [D loss: 1.280580] [G loss: 3.179517]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 116/1170] [D loss: 2.209690] [G loss: 18.528051]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 117/1170] [D loss: 0.894192] [G loss: 4.042174]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 118/1170] [D loss: 1.722292] [G loss: 17.950951]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 119/1170] [D loss: 0.267752] [G loss: 16.830013]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 120/1170] [D loss: 1.218150] [G loss: 1.923408]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 121/1170] [D loss: 3.195751] [G loss: 20.050501]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 122/1170] [D loss: 1.139074] [G loss: 8.070160]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 123/1170] [D loss: 0.661694] [G loss: 11.247176]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 124/1170] [D loss: 0.395022] [G loss: 13.710867]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 125/1170] [D loss: 0.018675] [G loss: 8.733351]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 126/1170] [D loss: 0.064293] [G loss: 6.206559]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 127/1170] [D loss: 0.871161] [G loss: 14.382160]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 128/1170] [D loss: 0.049484] [G loss: 18.461065]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 129/1170] [D loss: 2.226687] [G loss: 2.561681]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 130/1170] [D loss: 10.536406] [G loss: 9.509350]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 131/1170] [D loss: 0.814899] [G loss: 21.011997]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 132/1170] [D loss: 0.300781] [G loss: 14.785849]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 133/1170] [D loss: 0.011510] [G loss: 13.531660]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 134/1170] [D loss: 0.420276] [G loss: 14.299226]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 135/1170] [D loss: 0.673292] [G loss: 4.400546]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 136/1170] [D loss: 1.218404] [G loss: 16.814966]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 137/1170] [D loss: 0.048833] [G loss: 16.595169]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 138/1170] [D loss: 2.019369] [G loss: 0.885643]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 139/1170] [D loss: 4.680134] [G loss: 13.873871]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 140/1170] [D loss: 1.060162] [G loss: 18.621426]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 141/1170] [D loss: 1.037551] [G loss: 4.828596]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 142/1170] [D loss: 0.746615] [G loss: 2.922224]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 143/1170] [D loss: 1.375341] [G loss: 8.557292]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 144/1170] [D loss: 0.977181] [G loss: 16.061806]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 145/1170] [D loss: 2.248363] [G loss: 2.048620]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 146/1170] [D loss: 1.873422] [G loss: 11.359910]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 147/1170] [D loss: 0.824250] [G loss: 4.943689]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 148/1170] [D loss: 1.772040] [G loss: 8.088001]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 149/1170] [D loss: 0.451943] [G loss: 5.497287]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 150/1170] [D loss: 1.141203] [G loss: 21.445044]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 151/1170] [D loss: 2.818093] [G loss: 6.598768]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 152/1170] [D loss: 0.016879] [G loss: 8.444936]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 153/1170] [D loss: 1.967145] [G loss: 18.337383]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 154/1170] [D loss: 1.113519] [G loss: 15.760433]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 155/1170] [D loss: 3.844408] [G loss: 0.193092]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 156/1170] [D loss: 1.688738] [G loss: 3.462834]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 157/1170] [D loss: 0.844491] [G loss: 9.633301]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 158/1170] [D loss: 0.802636] [G loss: 12.160460]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 159/1170] [D loss: 1.308921] [G loss: 5.480483]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 160/1170] [D loss: 0.594323] [G loss: 4.278577]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 161/1170] [D loss: 1.200665] [G loss: 8.358273]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 162/1170] [D loss: 0.558454] [G loss: 7.494396]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 163/1170] [D loss: 0.449040] [G loss: 6.810513]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 164/1170] [D loss: 0.070386] [G loss: 5.149751]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 165/1170] [D loss: 1.203225] [G loss: 6.786259]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 166/1170] [D loss: 0.105812] [G loss: 8.661023]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 167/1170] [D loss: 1.359845] [G loss: 3.173403]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 168/1170] [D loss: 0.201303] [G loss: 8.007611]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 169/1170] [D loss: 0.439372] [G loss: 2.032893]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 170/1170] [D loss: 0.442783] [G loss: 9.009476]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 171/1170] [D loss: 0.220343] [G loss: 8.294249]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 172/1170] [D loss: 0.295759] [G loss: 5.196084]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 173/1170] [D loss: 0.322607] [G loss: 10.403152]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 174/1170] [D loss: 0.183731] [G loss: 7.937500]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 175/1170] [D loss: 0.053438] [G loss: 6.407311]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 176/1170] [D loss: 0.006106] [G loss: 7.146888]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 177/1170] [D loss: 0.760192] [G loss: 9.593505]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 178/1170] [D loss: 0.717830] [G loss: 5.009102]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 179/1170] [D loss: 0.310672] [G loss: 7.804281]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 180/1170] [D loss: 0.139300] [G loss: 8.587309]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 181/1170] [D loss: 0.651790] [G loss: 3.533878]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 182/1170] [D loss: 1.866899] [G loss: 16.854481]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 183/1170] [D loss: 1.529986] [G loss: 4.917974]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 184/1170] [D loss: 2.280553] [G loss: 9.392767]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 185/1170] [D loss: 0.463003] [G loss: 13.341106]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 186/1170] [D loss: 0.329423] [G loss: 10.408591]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 187/1170] [D loss: 0.960570] [G loss: 0.473416]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 188/1170] [D loss: 1.033264] [G loss: 9.557648]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 189/1170] [D loss: 0.370696] [G loss: 10.014168]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 190/1170] [D loss: 1.015018] [G loss: 1.312269]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# ...
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1059/1170] [D loss: 0.723207] [G loss: 2.732551]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1060/1170] [D loss: 0.326941] [G loss: 6.074029]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1061/1170] [D loss: 0.975304] [G loss: 2.202867]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1062/1170] [D loss: 1.058620] [G loss: 5.313821]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1063/1170] [D loss: 0.965799] [G loss: 3.077368]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1064/1170] [D loss: 0.253048] [G loss: 2.459741]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1065/1170] [D loss: 0.501873] [G loss: 6.685138]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1066/1170] [D loss: 1.483551] [G loss: 0.111248]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1067/1170] [D loss: 1.048593] [G loss: 5.528849]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1068/1170] [D loss: 0.650879] [G loss: 2.622945]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1069/1170] [D loss: 0.424932] [G loss: 4.048828]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1070/1170] [D loss: 0.820321] [G loss: 2.629724]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1071/1170] [D loss: 0.506856] [G loss: 2.167851]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1072/1170] [D loss: 1.625370] [G loss: 3.661212]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1073/1170] [D loss: 0.552282] [G loss: 3.212058]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1074/1170] [D loss: 0.330479] [G loss: 3.171381]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1075/1170] [D loss: 0.599642] [G loss: 5.291248]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1076/1170] [D loss: 0.096867] [G loss: 5.919194]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1077/1170] [D loss: 0.954348] [G loss: 1.197866]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1078/1170] [D loss: 2.223193] [G loss: 4.736898]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1079/1170] [D loss: 0.714230] [G loss: 5.592175]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1080/1170] [D loss: 1.337076] [G loss: 0.707153]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1081/1170] [D loss: 0.904459] [G loss: 3.757136]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1082/1170] [D loss: 1.551560] [G loss: 3.321441]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1083/1170] [D loss: 0.762380] [G loss: 1.106103]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1084/1170] [D loss: 0.531990] [G loss: 6.377178]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1085/1170] [D loss: 1.275426] [G loss: 1.928510]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1086/1170] [D loss: 0.690579] [G loss: 1.480142]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1087/1170] [D loss: 1.681322] [G loss: 2.819531]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1088/1170] [D loss: 0.352739] [G loss: 3.488825]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1089/1170] [D loss: 0.705429] [G loss: 5.268272]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1090/1170] [D loss: 0.730770] [G loss: 1.846597]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1091/1170] [D loss: 0.319227] [G loss: 4.402994]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1092/1170] [D loss: 0.757146] [G loss: 2.697341]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1093/1170] [D loss: 0.491367] [G loss: 2.388341]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1094/1170] [D loss: 1.913594] [G loss: 2.299543]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1095/1170] [D loss: 0.734168] [G loss: 2.399704]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1096/1170] [D loss: 0.998645] [G loss: 2.612455]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1097/1170] [D loss: 0.526642] [G loss: 4.245101]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1098/1170] [D loss: 2.878139] [G loss: 0.670903]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1099/1170] [D loss: 1.017186] [G loss: 3.472985]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1100/1170] [D loss: 0.792041] [G loss: 2.063588]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1101/1170] [D loss: 1.338854] [G loss: 1.656404]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1102/1170] [D loss: 0.513079] [G loss: 0.906848]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1103/1170] [D loss: 0.923153] [G loss: 3.341590]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1104/1170] [D loss: 0.564688] [G loss: 3.053927]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1105/1170] [D loss: 0.419472] [G loss: 2.984584]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1106/1170] [D loss: 0.381839] [G loss: 3.429261]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1107/1170] [D loss: 0.875712] [G loss: 1.047722]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1108/1170] [D loss: 0.241472] [G loss: 3.184264]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1109/1170] [D loss: 0.448598] [G loss: 2.028365]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1110/1170] [D loss: 1.673074] [G loss: 3.957530]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1111/1170] [D loss: 1.163518] [G loss: 2.064256]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1112/1170] [D loss: 0.310135] [G loss: 3.081156]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1113/1170] [D loss: 0.740476] [G loss: 4.864328]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1114/1170] [D loss: 0.513624] [G loss: 1.664728]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1115/1170] [D loss: 0.412709] [G loss: 1.987677]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1116/1170] [D loss: 0.510816] [G loss: 1.373763]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1117/1170] [D loss: 0.259091] [G loss: 3.628572]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1118/1170] [D loss: 0.479591] [G loss: 4.005541]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1119/1170] [D loss: 0.162263] [G loss: 3.680900]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1120/1170] [D loss: 0.110368] [G loss: 4.219306]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1121/1170] [D loss: 0.352231] [G loss: 1.331776]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1122/1170] [D loss: 1.395997] [G loss: 2.141870]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1123/1170] [D loss: 0.504983] [G loss: 1.982212]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1124/1170] [D loss: 0.473281] [G loss: 0.501509]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1125/1170] [D loss: 1.343489] [G loss: 5.249820]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1126/1170] [D loss: 0.079768] [G loss: 6.044231]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1127/1170] [D loss: 0.874722] [G loss: 1.941857]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1128/1170] [D loss: 1.304979] [G loss: 4.534891]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1129/1170] [D loss: 0.468782] [G loss: 3.386554]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1130/1170] [D loss: 0.501291] [G loss: 1.456099]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1131/1170] [D loss: 0.668072] [G loss: 4.794252]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1132/1170] [D loss: 0.138385] [G loss: 4.087079]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1133/1170] [D loss: 0.265133] [G loss: 2.757506]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1134/1170] [D loss: 0.373446] [G loss: 1.566053]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1135/1170] [D loss: 1.679785] [G loss: 5.418172]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1136/1170] [D loss: 0.625865] [G loss: 2.602687]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1137/1170] [D loss: 0.386795] [G loss: 1.512587]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1138/1170] [D loss: 0.738347] [G loss: 4.876769]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1139/1170] [D loss: 1.470013] [G loss: 0.046357]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1140/1170] [D loss: 0.794041] [G loss: 5.447465]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1141/1170] [D loss: 0.564780] [G loss: 2.773501]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1142/1170] [D loss: 0.247388] [G loss: 3.396227]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1143/1170] [D loss: 0.863230] [G loss: 2.615240]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1144/1170] [D loss: 0.524894] [G loss: 4.156521]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1145/1170] [D loss: 0.135865] [G loss: 3.807481]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1146/1170] [D loss: 0.631996] [G loss: 2.384317]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1147/1170] [D loss: 0.268766] [G loss: 5.663607]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1148/1170] [D loss: 0.147484] [G loss: 4.562389]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1149/1170] [D loss: 0.601643] [G loss: 1.149943]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1150/1170] [D loss: 0.602557] [G loss: 5.714707]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1151/1170] [D loss: 0.608191] [G loss: 3.274104]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1152/1170] [D loss: 0.193449] [G loss: 3.084630]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1153/1170] [D loss: 0.434049] [G loss: 5.681781]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1154/1170] [D loss: 0.354516] [G loss: 3.392957]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1155/1170] [D loss: 0.416457] [G loss: 1.421502]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1156/1170] [D loss: 1.276924] [G loss: 8.417360]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1157/1170] [D loss: 0.314842] [G loss: 6.691058]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1158/1170] [D loss: 1.257114] [G loss: 1.448311]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1159/1170] [D loss: 1.631911] [G loss: 4.854351]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1160/1170] [D loss: 0.809367] [G loss: 2.724505]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1161/1170] [D loss: 0.448513] [G loss: 1.441517]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1162/1170] [D loss: 1.665219] [G loss: 7.327867]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1163/1170] [D loss: 0.620821] [G loss: 1.681508]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1164/1170] [D loss: 0.882282] [G loss: 5.110576]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1165/1170] [D loss: 1.423548] [G loss: 0.736835]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1166/1170] [D loss: 1.256070] [G loss: 3.231755]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1167/1170] [D loss: 0.713111] [G loss: 7.169838]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1168/1170] [D loss: 1.873250] [G loss: 1.740774]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 0/100] [Batch 1169/1170] [D loss: 1.829809] [G loss: 0.174570]
# [GPU Memory Allocated: 0.99 GB] [GPU Memory Reserved: 6.31 GB]
# [Epoch 1/100] [Batch 0/1170] [D loss: 2.327648] [G loss: 1.564294]
# [GPU Memory Allocated: 1.01 GB] [GPU Memory Reserved: 7.19 GB]
# [Epoch 1/100] [Batch 1/1170] [D loss: 0.590326] [G loss: 2.904534]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 7.19 GB]
# [Epoch 1/100] [Batch 2/1170] [D loss: 1.101736] [G loss: 2.073700]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 7.19 GB]
# [Epoch 1/100] [Batch 3/1170] [D loss: 0.480368] [G loss: 2.860691]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 7.19 GB]
# [Epoch 1/100] [Batch 4/1170] [D loss: 0.602909] [G loss: 1.764251]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 7.19 GB]
# [Epoch 1/100] [Batch 5/1170] [D loss: 0.527989] [G loss: 1.816478]
# [GPU Memory Allocated: 1.00 GB] [GPU Memory Reserved: 7.19 GB]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
